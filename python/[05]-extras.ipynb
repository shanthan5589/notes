# %%
# This notebook contains a list of methods of each data type that have "NOT" been covered in methods.ipynb

# %%
# LIST

```
__add__
__init__
__str__
__iadd__
__ne__
__repr__
__reversed__
__len__
__lt__
__contains__
__iter__
__doc__
__le__
__setitem__
__hash__
__imul__
__rmul__
__reduce__
__sizeof__
__reduce_ex__
__class_getitem__
__init_subclass__
__subclasshook__
__delattr__
__class__
__delitem__
__new__
__dir__
__mul__
__ge__
__getstate__
__format__
__gt__
__getitem__
__eq__
__setattr__
__getattribute__

```

# %%
# String

```
removesuffix
removeprefix
istitle
isspace
isprintable
isdigit
isascii
isnumeric
maketrans
swapcase
rpartition
partition
rsplit
splitlines
encode
format_map
expandtabs
title
translate

__add__
__init__
__str__
__ne__
__repr__
__rmod__
__getattribute__
__len__
__lt__
__contains__
__iter__
__doc__
__le__
__getnewargs__
__hash__
__mod__
__rmul__
__reduce__
__setattr__
__sizeof__
__reduce_ex__
__init_subclass__
__subclasshook__
__delattr__
__class__
__new__
__dir__
__mul__
__ge__
__getstate__
__format__
__gt__
__getitem__
__eq__

```

# %%
# Dictionary

```
popitem
setdefault

__str__
__init__
__ne__
__repr__
__reversed__
__len__
__lt__
__contains__
__iter__
__doc__
__le__
__setitem__
__hash__
__ror__
__reduce__
__sizeof__
__reduce_ex__
__class_getitem__
__init_subclass__
__subclasshook__
__delattr__
__class__
__delitem__
__new__
__dir__
__or__
__ge__
__getstate__
__format__
__gt__
__ior__
__getitem__
__eq__
__setattr__
__getattribute__

```

# %%
# Set

```
issuperset
issubset
isdisjoint
pop

__str__
__init__
__ne__
__repr__
__xor__
__isub__
__ixor__
__len__
__lt__
__contains__
__iter__
__doc__
__le__
__rsub__
__hash__
__ror__
__reduce__
__iand__
__sizeof__
__reduce_ex__
__class_getitem__
__init_subclass__
__subclasshook__
__delattr__
__sub__
__class__
__new__
__dir__
__or__
__ge__
__getstate__
__and__
__format__
__gt__
__ior__
__rxor__
__eq__
__setattr__
__getattribute__
__rand__

```
